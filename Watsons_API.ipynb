# %%
import json
from watson_developer_cloud import VisualRecognitionV3
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
im = Image.open('dog.jpg')
plt.imshow(im)
plt.title('dog')
plt.show()

# %%
visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_apikey='IJI1VtmJfiWRxcqsv1K5F-wGjQ_CzrqT2xat_h0ln6cJ')
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
with open('dog.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
	classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "retriever dog",
#               "score": 0.692
#             },
#             {
#               "class": "dog",
#               "score": 0.83
#             },
#             {
#               "class": "domestic animal",
#               "score": 0.832
#             },
#             {
#               "class": "animal",
#               "score": 0.836
#             },
#             {
#               "class": "light brown color",
#               "score": 0.708
#             },
#             {
#               "class": "pale yellow color",
#               "score": 0.694
#             }
#           ]
#         }
#       ],
#       "image": "dog.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 0
# }
